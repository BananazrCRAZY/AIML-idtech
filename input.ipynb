# %%
input("input you're asking for")
# Out:
# input you're asking forjh
# 'jh'

# %%
print(input("name?\n"))
# Out:
# name?
# kj
# kj

# %%
print(int(input("age?")) + 3)
# Out:
# age?7
# 10

# %%
print("Hi, my name is " + input("your name?\n"))
