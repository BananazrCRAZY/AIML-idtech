# %%
print(int(input("input int")) + int(input("input another int")))
# Out:
# input int5
# input another int6
# 11

# %%
print("Hello " + input("what is your name?\n") + " u r cool")
# Out:
# what is your name?
# john
# Hello john u r cool
