# %%
print("i alr did this")
print("so ig ill do this again")
print("this is such a fun story")
print("r u enjoying the story of me not having any imagination")
print("i basically did all of day 1 alr and some of day 2")
print("this story is entertaining isnt it")
print("im brain dead")
# Out:
# i alr did this
# so ig ill do this again
# this is such a fun story
# r u enjoying the story of me not having any imagination
# i basically did all of day 1 alr and some of day 2
# this story is entertaining isnt it
# im brain dead
