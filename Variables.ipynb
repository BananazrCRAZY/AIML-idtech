# %%
number_of_donuts = 3
print(number_of_donuts)
# Out:
# 3

# %%
number_of_donuts = 6
print(number_of_donuts)
# Out:
# 6

# %%
donut_name = "kelper"
print(donut_name)
# Out:
# kelper

# %%
donuts_exist = True
print(donuts_exist)
# Out:
# True
